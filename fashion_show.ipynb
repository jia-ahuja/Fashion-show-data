# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## 1. Getting the brand names and links to their pages on the fashiongo website.

# %%
def get_response(page):
  cookies = {
      'PHPSESSID': 'tf28hau9sb1v1rna0ud2l7a1mt',
      'token': '',
      'fingerprint': '{%22hash%22:%2222a4ec6ee69d98b9b830f473cf0a984f%22%2C%22expire%22:1723618476768}',
      'lang': 'en',
      'initiated': 'true',
      '_gcl_au': '1.1.485309854.1723618475',
      '_gid': 'GA1.2.1543129195.1723618475',
      '__adroll_fpc': '497eaeb49d5285f915946c272f26f68f-1723618474987',
      '_fbp': 'fb.1.1723618475013.922187955361607193',
      'sa-user-id': 's%253A0-68c9aa06-cb66-5519-42b3-627ba88d9f51.g7inWl%252BpsgNOw7tWXmTa2TnzZyIc0ajzmvkQR35DyaM',
      'sa-user-id-v2': 's%253AaMmqBstmVRlCs2J7qI2fUXqtNDU.r2o0cjXblM7XrF%252Frao9LVofpHa%252B5MfQdU2CjjHN8YXw',
      '_ga_D5DTKS92FY': 'GS1.1.1723618474.1.1.1723619206.57.0.0',
      '_ga': 'GA1.2.1342213515.1723618475',
      'sa-user-id-v3': 's%253AAQAKIEV3nHtHhsDbPrENaZQK9TlviAKPwJx9o2kNaCXOjibaEAEYAyCGr_G1BjABOgQIcZpRQgQ8BGN3.h4ZHvfhTdh3f2TZXo6Lh%252BrzdwFsCrKoojf6WVyt2w40',
      '_uetsid': '1107cd505a0a11ef8d97fd98ff626aff',
      '_uetvid': '110802705a0a11ef868253527f54773b',
      '_ga_Z1MXMM07MD': 'GS1.2.1723618475.1.1.1723619207.60.0.0',
      '_ga_ZW14YV410F': 'GS1.2.1723618475.1.1.1723619207.60.0.0',
      '_ga_8Q8SRD3TS6': 'GS1.2.1723618475.1.1.1723619207.60.0.0',
      '_ga_YECTYL1G2H': 'GS1.2.1723618475.1.1.1723619207.60.0.0',
      '_ga_9H00DCKH9D': 'GS1.2.1723618475.1.1.1723619207.60.0.0',
      '__ar_v4': 'TEMSL5ZVCRCB7K5U2JRDTT%3A20240813%3A10%7CBDKZPM66SZFIRNQYXFOZLE%3A20240813%3A10%7CWWOS4ICHXVGNLFD5AEV4WY%3A20240813%3A10',
  }

  headers = {
      'accept': '*/*',
      'accept-language': 'en-US,en;q=0.9',
      'content-type': 'application/json',
      # 'cookie': 'PHPSESSID=tf28hau9sb1v1rna0ud2l7a1mt; token=; fingerprint={%22hash%22:%2222a4ec6ee69d98b9b830f473cf0a984f%22%2C%22expire%22:1723618476768}; lang=en; initiated=true; _gcl_au=1.1.485309854.1723618475; _gid=GA1.2.1543129195.1723618475; __adroll_fpc=497eaeb49d5285f915946c272f26f68f-1723618474987; _fbp=fb.1.1723618475013.922187955361607193; sa-user-id=s%253A0-68c9aa06-cb66-5519-42b3-627ba88d9f51.g7inWl%252BpsgNOw7tWXmTa2TnzZyIc0ajzmvkQR35DyaM; sa-user-id-v2=s%253AaMmqBstmVRlCs2J7qI2fUXqtNDU.r2o0cjXblM7XrF%252Frao9LVofpHa%252B5MfQdU2CjjHN8YXw; _ga_D5DTKS92FY=GS1.1.1723618474.1.1.1723619206.57.0.0; _ga=GA1.2.1342213515.1723618475; sa-user-id-v3=s%253AAQAKIEV3nHtHhsDbPrENaZQK9TlviAKPwJx9o2kNaCXOjibaEAEYAyCGr_G1BjABOgQIcZpRQgQ8BGN3.h4ZHvfhTdh3f2TZXo6Lh%252BrzdwFsCrKoojf6WVyt2w40; _uetsid=1107cd505a0a11ef8d97fd98ff626aff; _uetvid=110802705a0a11ef868253527f54773b; _ga_Z1MXMM07MD=GS1.2.1723618475.1.1.1723619207.60.0.0; _ga_ZW14YV410F=GS1.2.1723618475.1.1.1723619207.60.0.0; _ga_8Q8SRD3TS6=GS1.2.1723618475.1.1.1723619207.60.0.0; _ga_YECTYL1G2H=GS1.2.1723618475.1.1.1723619207.60.0.0; _ga_9H00DCKH9D=GS1.2.1723618475.1.1.1723619207.60.0.0; __ar_v4=TEMSL5ZVCRCB7K5U2JRDTT%3A20240813%3A10%7CBDKZPM66SZFIRNQYXFOZLE%3A20240813%3A10%7CWWOS4ICHXVGNLFD5AEV4WY%3A20240813%3A10',
      'origin': 'https://lasvegasaug.fashionresource.com',
      'priority': 'u=1, i',
      'referer': 'https://lasvegasaug.fashionresource.com/newfront/marketplace/exhibitors?pageNumber=1&limit=12',
      'sec-ch-ua': '"Not)A;Brand";v="99", "Microsoft Edge";v="127", "Chromium";v="127"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 Edg/127.0.0.0',
      'x-application': '3',
      'x-fp': '22a4ec6ee69d98b9b830f473cf0a984f',
      'x-lang': 'en',
      'x-real-origin': '/marketplace/exhibitors?pageNumber=1&limit=12',
      'x-real-refer': '/marketplace/exhibitors?pageNumber=1',
  }

  json_data = {
      'page': page,
      'limit': 60,
      'nextResult': {},
  }

  response = requests.post(
      'https://lasvegasaug.fashionresource.com/api/v1/search/exhibitors',
      cookies=cookies,
      headers=headers,
      json=json_data,
  )

  return response.json()['data']['list']

# %%
page = 1
result = []
while True:
  data = get_response(page)
  if len(data) == 0:
    break
  for row in data:
    result.append({'name':row['name'], 'url':row['url']})
  page += 1
# Out:
# on page 1
# found data
# on page 2
# found data
# on page 3
# found data
# on page 4
# found data
# on page 5
# found data
# on page 6
# found data
# on page 7
# found data
# on page 8
# found data
# on page 9
# found data
# on page 10
# found data
# on page 11
# found data
# on page 12
# found data
# on page 13
# found data
# on page 14
# found data
# on page 15
# found data
# on page 16
# found data
# on page 17
# found data
# on page 18
# found data
# on page 19
# found data
# on page 20
# found data
# on page 21
# found data
# on page 22
# found data
# on page 23
# found data
# on page 24
# found data
# on page 25
# found data
# on page 26
# found data
# on page 27
# found data
# on page 28
# found data
# on page 29
# found data
# on page 30
# found data
# on page 31
# found data
# on page 32
# found data
# on page 33
# found data
# on page 34
# found data
# on page 35
# found data
# on page 36
# found data
# on page 37
# found data
# on page 38
# found data
# on page 39
# ...

# %%
final_data = pd.DataFrame(result)

# %%
final_data
# Out:
#                          name                      url
# 0                   11 Uptown       11-uptown-49a1dc1b
# 1                  1822 Denim      1822-denim-38421386
# 2                     1-Beast                  1-beast
# 3               1 Sunset Lane   1-sunset-lane-e3f12718
# 4                   24Colours       24colours-6b6f8d50
# ...                       ...                      ...
# 2619              Zorro Stuff              zorro-stuff
# 2620  Z Sulehri International  z-sulehri-international
# 2621                 Z Supply        z-supply-bc15c6dd
# 2622                   Zutter          zutter-57b383c6
# 2623                     ZYOD                     zyod
#
# [2624 rows x 2 columns]

# %% [markdown]
# ## 2. Now going to the brands' fashiongo page and extracting the URL to their primary website.

# %%
def get_website(url):
  import requests
  import json

  cookies = {
      'PHPSESSID': 'tf28hau9sb1v1rna0ud2l7a1mt',
      'token': '',
      'fingerprint': '{%22hash%22:%2222a4ec6ee69d98b9b830f473cf0a984f%22%2C%22expire%22:1723618476768}',
      'lang': 'en',
      'initiated': 'true',
      '_gcl_au': '1.1.485309854.1723618475',
      '_gid': 'GA1.2.1543129195.1723618475',
      '__adroll_fpc': '497eaeb49d5285f915946c272f26f68f-1723618474987',
      '_fbp': 'fb.1.1723618475013.922187955361607193',
      'sa-user-id': 's%253A0-68c9aa06-cb66-5519-42b3-627ba88d9f51.g7inWl%252BpsgNOw7tWXmTa2TnzZyIc0ajzmvkQR35DyaM',
      'sa-user-id-v2': 's%253AaMmqBstmVRlCs2J7qI2fUXqtNDU.r2o0cjXblM7XrF%252Frao9LVofpHa%252B5MfQdU2CjjHN8YXw',
      '_ga_D5DTKS92FY': 'GS1.1.1723618474.1.1.1723620919.27.0.0',
      '_ga': 'GA1.1.1342213515.1723618475',
      '_ga_ZW14YV410F': 'GS1.2.1723618475.1.1.1723620919.60.0.0',
      '_ga_YECTYL1G2H': 'GS1.2.1723618475.1.1.1723620919.60.0.0',
      '_ga_9H00DCKH9D': 'GS1.2.1723618475.1.1.1723620919.60.0.0',
      '_ga_Z1MXMM07MD': 'GS1.2.1723618475.1.1.1723620919.60.0.0',
      '_ga_8Q8SRD3TS6': 'GS1.2.1723618475.1.1.1723620919.60.0.0',
      '_uetsid': '1107cd505a0a11ef8d97fd98ff626aff',
      '_uetvid': '110802705a0a11ef868253527f54773b',
      'sa-user-id-v3': 's%253AAQAKIEV3nHtHhsDbPrENaZQK9TlviAKPwJx9o2kNaCXOjibaEAEYAyC2vPG1BjABOgQIcZpRQgRfqIuz.4yi1LtuxKmSsLVzwaBjL9qkRod9JzPHDB0A8QGwN6sY',
      '__ar_v4': 'TEMSL5ZVCRCB7K5U2JRDTT%3A20240813%3A16%7CBDKZPM66SZFIRNQYXFOZLE%3A20240813%3A16%7CWWOS4ICHXVGNLFD5AEV4WY%3A20240813%3A16',
  }

  headers = {
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
      'accept-language': 'en-US,en;q=0.9',
      'cache-control': 'no-cache, no-store, must-revalidate',
      'pragma': 'no-cache',
      'expires': '0',
      'priority': 'u=0, i',
      'sec-ch-ua': '"Not)A;Brand";v="99", "Microsoft Edge";v="127", "Chromium";v="127"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'document',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-site': 'same-origin',
      'sec-fetch-user': '?1',
      'upgrade-insecure-requests': '1',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 Edg/127.0.0.0',
  }

  site = f'https://lasvegasaug.fashionresource.com/newfront/exhibitor/{url}'
  response = requests.get(
      site,
      cookies=cookies,
      headers=headers,
  )

  soup = BeautifulSoup(response.text, 'html.parser')

  # Find the script tag with id "__NEXT_DATA__"
  script_tag = soup.find('script', id='__NEXT_DATA__')

  if script_tag:
      # Extract the JSON string
      json_str = script_tag.string

      # Parse the JSON string into a Python dictionary
      data = json.loads(json_str)
      r = data['props']['pageProps']['controlItem']['website']
      if r != None or r != '':
        return data['props']['pageProps']['controlItem']['website']
      else:
        return site

# %%
from tqdm import tqdm
websites = []
for url in tqdm(final_data['url']):
  websites.append(get_website(url))
# Out:
# 100%|██████████| 2624/2624 [37:26<00:00,  1.17it/s]

# %%
final_data['website'] = websites

# %%
final_data
# Out:
#                          name                      url  \
# 0                   11 Uptown       11-uptown-49a1dc1b
# 1                  1822 Denim      1822-denim-38421386
# 2                     1-Beast                  1-beast
# 3               1 Sunset Lane   1-sunset-lane-e3f12718
# 4                   24Colours       24colours-6b6f8d50
# ...                       ...                      ...
# 2619              Zorro Stuff              zorro-stuff
# 2620  Z Sulehri International  z-sulehri-international
# 2621                 Z Supply        z-supply-bc15c6dd
# 2622                   Zutter          zutter-57b383c6
# 2623                     ZYOD                     zyod
#
#                       website
# 0            www.11uptown.com
# 1           www.1822denim.com
# 2
# 3     www.26international.com
# 4           www.24colours.com
# ...                       ...
# 2619       www.zorrostuff.com
# 2620
# 2621  www.zsupplyclothing.com
# 2622           www.zutter.com
# 2623
#
# ...

# %%
final_data.to_csv('upwork_fashion_show.csv', sep='|', index=False)
